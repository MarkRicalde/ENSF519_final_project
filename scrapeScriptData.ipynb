# %% [markdown]
# ## Final Project

# %% [markdown]
# #### Scrape script data

# %%
import csv
import os
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

oscar_data = pd.read_csv('oscar_data.csv')

def write_script_data(movie_script_dict):
    filename = 'movie_scripts.csv'
    if os.path.exists(filename):
        append_write = 'a' # append if already exists
    else:
        append_write = 'w' # make a new file if not
    with open(filename, append_write, newline='') as infile:
        writer = csv.writer(infile)
        for key in movie_script_dict:
            if movie_script_dict[key] != None:
                try:
                    print('Flushing to csv: {}'.format(key))
                    year,script = movie_script_dict[key]
                    writer.writerow([key, year, script])
                except TypeError as e:
                    print('Error, skipping writing this movie script...')
                    print(e)
                    print(key)
                    print(movie_script_dict[key])

def get_movie_script(movie_name, year):
    # Search to see if movie in Springfield database
    print('Searching db for: {}'.format(movie_name))
    movie_script_url = r'https://www.springfieldspringfield.co.uk/movie_scripts.php?search={}'.format(movie_name)
    data = requests.get(movie_script_url).text
    parser = BeautifulSoup(data, 'html.parser')
    tags = parser.find_all('a', {'class':"script-list-item"}) # Should find first search item
    if tags == None:
        return None
    script_url = None
    for movie_tag in tags:
        result_text = movie_tag.text
        match = re.search('(.+) \((\d\d\d\d)\)', movie_tag.text)
        if match == None:
            return None
        tag_title = match.group(1)
        tag_year = int(match.group(2))
        # Only match if name is exact, and year within +-1
        if tag_title == movie_name and abs(year - tag_year) <= 1:
            script_url = 'https://www.springfieldspringfield.co.uk/{}'.format(movie_tag['href'])
            break
    if not script_url:
        return None

    # Get the script text from another url
    print(' Gathering script...')
    script_html = requests.get(script_url).text
    parser = BeautifulSoup(script_html, 'html.parser')
    script_container = parser.find('div', {'class':"scrolling-script-container"})
    script = script_container.text.strip()
    return script

# print(get_movie_script('Trading Places', 1983))

movie_set = set()
for index,row in oscar_data.iterrows():
    movie_set.add((row['entity'], row['year']))

movie_script_dict = {}
flush_count = 0
total_count = 0
for movie_name, year in movie_set:
    if movie_name in movie_script_dict:
        continue
    try:
        script = get_movie_script(movie_name, year)
    except Exception as e:
        print(' Error getting html data...')
        print(e)
        continue
    if script == None:
        continue
    movie_script_dict[movie_name] = (year,script)
    flush_count += 1
    
    # Flush to file when dict gets too large
    if flush_count >= 10:
        write_script_data(movie_script_dict)
        movie_script_dict = dict.fromkeys(movie_script_dict, None)
        flush_count = 0
# Out:
# Searching db for: The Fight for Life
# Searching db for: Trading Places
#  Gathering script...
# Searching db for: The Dawn Patrol
# Searching db for: The Devil and Miss Jones
#  Gathering script...
# Searching db for: Millions of Years Ahead of Man
# Searching db for: Marjoe
# Searching db for: Restrepo
#  Gathering script...
# Searching db for: Black and White in Color
# Searching db for: Witness
#  Gathering script...
# Searching db for: Mask
#  Gathering script...
# Searching db for: Brokeback Mountain
#  Gathering script...
# Searching db for: The Snake Pit
#  Gathering script...
# Searching db for: Kolya
# Searching db for: Fourteen Hours
#  Gathering script...
# Searching db for: Jimmy Neutron: Boy Genius
#  Gathering script...
# Searching db for: Good Will Hunting
#  Gathering script...
# Flushing to csv: Trading Places
# Flushing to csv: The Devil and Miss Jones
# Flushing to csv: Restrepo
# Flushing to csv: Witness
# Flushing to csv: Mask
# Flushing to csv: Brokeback Mountain
# Flushing to csv: The Snake Pit
# Flushing to csv: Fourteen Hours
# Flushing to csv: Jimmy Neutron: Boy Genius
# Flushing to csv: Good Will Hunting
# Searching db for: Balseros
# Searching db for: Who Framed Roger Rabbit
#  Gathering script...
# Searching db for: Lady on a Train
#  Gathering script...
# Searching db for: Oktapodi
# Searching db for: Easy Rider
#  Gathering script...
# Searching db for: The Gorgeous Hussy
# Searching db for: The House without a Name
# Searching db for: American Splendor
#  Gathering script...
# Searching db for: Lou
# Searching db for: Two Girls and a Sailor
# Searching db for: One-Eyed Men Are Kings
# Searching db for: Lady and Gent
# Searching db for: The Dutch Tradition
# Searching db for: The Story of the Weeping Camel
# Searching db for: Born Free
#  Gathering script...
# Searching db for: Blake
# Searching db for: Last Tango in Paris
# Searching db for: Royal Wedding
#  Gathering script...
# Searching db for: Interviews with My Lai Veterans
# Searching db for: Star Wars Episode I: The Phantom Menace
# Searching db for: Cross Creek
#  Gathering script...
# Searching db for: Pieces of Dreams
# Searching db for: Morituri
#  Gathering script...
# Searching db for: Suddenly, Last Summer
#  Gathering script...
# Searching db for: The Secret of Santa Vittoria
# Searching db for: California Suite
#  Gathering script...
# Flushing to csv: Who Framed Roger Rabbit
# Flushing to csv: Lady on a Train
# Flushing to csv: Easy Rider
# Flushing to csv: American Splendor
# Flushing to csv: Born Free
# Flushing to csv: Royal Wedding
# Flushing to csv: Cross Creek
# Flushing to csv: Morituri
# Flushing to csv: Suddenly, Last Summer
# Flushing to csv: California Suite
# Searching db for: I Dream Too Much
# Searching db for: Fires of Kuwait
# Searching db for: Skyscraper
# Searching db for: Feral
# Searching db for: The Wolf Men
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-f289e44d0734> in <module>
#      74     try:
# ---> 75         script = get_movie_script(movie_name, year)
#      76     except Error as e:
#
# <ipython-input-54-f289e44d0734> in get_movie_script(movie_name, year)
#      33     movie_script_url = r'https://www.springfieldspringfield.co.uk/movie_scripts.php?search={}'.format(movie_name)
# ---> 34     data = requests.get(movie_script_url).text
#      35     parser = BeautifulSoup(data, 'html.parser')
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in connect(self)
#     393             server_hostname=server_hostname,
# --> 394             ssl_context=context,
#     395         )
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# c:\users\paulc\appdata\local\programs\python\python37\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f289e44d0734> in <module>
#      74     try:
#      75         script = get_movie_script(movie_name, year)
# ---> 76     except Error as e:
#      77         print(' Error getting html data...')
#      78         print(e)
#
# NameError: name 'Error' is not defined
