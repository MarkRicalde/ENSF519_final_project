# %% [markdown]
# ### Scrape imdb data

# %%
import pandas as pd
from urllib.parse import quote
import requests
import json

response_data = []
title_year_set = set()

api_key = '9c9cdc81'
api_url = 'http://www.omdbapi.com/?t={}&y={}&apikey={}'

oscar_data = pd.read_csv('oscar_data.csv')
titles_and_years = oscar_data[['year', 'entity']]

for index, row in titles_and_years.iterrows():
    title_year_set.add((row['entity'], row['year']))

    
title_year_set = sorted(title_year_set)
counter = 0
for title, year in title_year_set:
    if counter < 4000:
        counter += 1
        continue
    if counter == 4500:
        break
    
    response_dict = dict()
    title = quote(title)
    url = api_url.format(title, year, api_key)
    response = requests.get(url)
    try:
        response_dict = json.loads(response.text)
    except:
        print('failed to parse for movie ', title)
        continue
    
    if response_dict['Response'] == 'False':
        prev_year = year - 1
        url = api_url.format(title, prev_year, api_key)
        response = requests.get(url)
        try:
            response_dict = json.loads(response.text)
        except:
            print('failed to parse for movie ', title)
            continue
        response_dict = json.loads(response.text)
    
    response_data.append(response_dict)
    counter += 1
    
response_data
# Out:
# [{'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'The War Game',
#   'Year': '1965',
#   'Rated': 'N/A',
#   'Released': '07 Feb 1967',
#   'Runtime': '48 min',
#   'Genre': 'Drama, War',
#   'Director': 'Peter Watkins',
#   'Writer': 'Peter Watkins',
#   'Actors': 'Michael Aspel, Peter Graham',
#   'Plot': 'A docudrama depicting a hypothetical nuclear attack on Britain.',
#   'Language': 'English',
#   'Country': 'UK',
#   'Awards': 'Won 1 Oscar. Another 4 wins.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZWRlODdjY2YtYmJhNy00NDE3LWFmOWMtOTUyOWZkOGUyOTI5XkEyXkFqcGdeQXVyMTk0MjQ3Nzk@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '8.0',
#   'imdbVotes': '5,755',
#   'imdbID': 'tt0059894',
#   'Type': 'movie',
#   'DVD': '04 Apr 1991',
#   'BoxOffice': 'N/A',
#   'Production': 'British Film Institute',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The War Room',
#   'Year': '1993',
#   'Rated': 'PG',
#   'Released': '01 Jan 1994',
#   'Runtime': '96 min',
#   'Genre': 'Documentary, History',
#   'Director': 'Chris Hegedus, D.A. Pennebaker',
#   'Writer': 'N/A',
#   'Actors': 'James Carville, George Stephanopoulos, Heather Beckel, Paul Begala',
#   'Plot': 'A documentary of the Bill Clinton 1992 presidential campaign and the organization who ran it.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 6 wins & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzU4NThlNmUtMDdiMi00NzgyLTk4MTQtZTI0NjQ2OTg0ZDFjXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '95%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.4',
#   'imdbVotes': '3,562',
#   'imdbID': 'tt0108515',
#   'Type': 'movie',
#   'DVD': '10 Nov 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'Criterion Collection',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The War Against Mrs. Hadley',
#   'Year': '1942',
#   'Rated': 'PASSED',
#   'Released': '04 Mar 1943',
#   'Runtime': '86 min',
#   'Genre': 'Drama',
#   'Director': 'Harold S. Bucquet',
#   'Writer': 'George Oppenheimer (original screenplay)',
#   'Actors': 'Edward Arnold, Fay Bainter, Richard Ney, Jean Rogers',
#   'Plot': 'A Washington official courts a society matron who is trying to ignore the effects of World War II.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYWNiZTg4ZDctMzIyOC00NzZlLWE5MjYtMmI5YTIyOGZkMzU0XkEyXkFqcGdeQXVyMTIxOTk5MzY@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.6',
#   'imdbVotes': '219',
#   'imdbID': 'tt0035531',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The War at Home',
#   'Year': '1979',
#   'Rated': 'Not Rated',
#   'Released': '01 Dec 1979',
#   'Runtime': '100 min',
#   'Genre': 'Documentary, History, Music, War',
#   'Director': 'Glenn Silber, Barry Alexander Brown(co-director)',
#   'Writer': 'N/A',
#   'Actors': 'Karleton Armstrong, Betty Boardman, Allen Ginsberg, Henry Haslach',
#   'Plot': 'Interviews with people involved with and leading the Madison, Wisconsin area resistance to the Vietnam war.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYmY0ZjgyYmEtMzNjNC00NDVhLWIyNjctNDZiMjFmOTM3YzRiXkEyXkFqcGdeQXVyNzI4MDMyMTU@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '191',
#   'imdbID': 'tt0080118',
#   'Type': 'movie',
#   'DVD': '16 Dec 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The War of the Worlds',
#   'Year': '1953',
#   'Rated': 'G',
#   'Released': '26 Aug 1953',
#   'Runtime': '85 min',
#   'Genre': 'Action, Sci-Fi, Thriller',
#   'Director': 'Byron Haskin',
#   'Writer': 'H.G. Wells (novel), Barré Lyndon (screenplay)',
#   'Actors': 'Gene Barry, Ann Robinson, Les Tremayne, Robert Cornthwaite',
#   'Plot': 'A small town in California is attacked by Martians, beginning a worldwide invasion.',
#   'Language': 'English, Spanish',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 4 wins & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYTViNjlmM2ItMmRhZC00ZDhkLWE2NTQtNzViMTgxNzY2MGY4XkEyXkFqcGdeQXVyNjEyNjA4ODg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Metascore': '78',
#   'imdbRating': '7.1',
#   'imdbVotes': '30,241',
#   'imdbID': 'tt0046534',
#   'Type': 'movie',
#   'DVD': '09 Sep 2008',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Warriors of Qiugang',
#   'Year': '2010',
#   'Rated': 'N/A',
#   'Released': '17 Sep 2010',
#   'Runtime': '39 min',
#   'Genre': 'Documentary, Short',
#   'Director': 'Ruby Yang',
#   'Writer': 'Thomas Lennon',
#   'Actors': 'Zhang Gongli, Wang Yongcui',
#   'Plot': 'Villagers in a remote district of central China take on a chemical company that is poisoning their water and air. For five years they fight to transform their environment and as they do, they find themselves transformed as well.',
#   'Language': 'Chinese',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5OTY5NDYwNV5BMl5BanBnXkFtZTcwNjk5MTkxNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.4',
#   'imdbVotes': '135',
#   'imdbID': 'tt1744887',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'Thomas Lennon Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Way Back',
#   'Year': '2010',
#   'Rated': 'PG-13',
#   'Released': '21 Jan 2011',
#   'Runtime': '133 min',
#   'Genre': 'Adventure, Drama, History',
#   'Director': 'Peter Weir',
#   'Writer': 'Keith R. Clarke (screenplay), Slavomir Rawicz (novel), Peter Weir (screenplay)',
#   'Actors': 'Dragos Bucur, Colin Farrell, Ed Harris, Alexandru Potocean',
#   'Plot': 'Siberian gulag escapees travel 4,000 miles by foot to freedom in India.',
#   'Language': 'Tibetan, Mongolian, English, Russian, Polish',
#   'Country': 'USA, United Arab Emirates, Poland, India',
#   'Awards': 'Nominated for 1 Oscar. Another 3 wins & 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MTc5MTM3Ml5BMl5BanBnXkFtZTcwMDI2NzgwNA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '7.3',
#   'imdbVotes': '103,440',
#   'imdbID': 'tt1023114',
#   'Type': 'movie',
#   'DVD': '22 Apr 2011',
#   'BoxOffice': '$2,500,000',
#   'Production': 'Newmarket Films LLC',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Way We Were',
#   'Year': '1973',
#   'Rated': 'PG',
#   'Released': '19 Oct 1973',
#   'Runtime': '118 min',
#   'Genre': 'Drama, Romance',
#   'Director': 'Sydney Pollack',
#   'Writer': 'Arthur Laurents',
#   'Actors': 'Barbra Streisand, Robert Redford, Bradford Dillman, Lois Chiles',
#   'Plot': 'Two disparate people have a wonderful romance, but their political views and convictions drive them apart.',
#   'Language': 'English, French',
#   'Country': 'USA',
#   'Awards': 'Won 2 Oscars. Another 5 wins & 7 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjFiM2IwN2MtNWQ3My00YmYwLTliMjYtMzZlMDQxZTdjNDA1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '65%'},
#    {'Source': 'Metacritic', 'Value': '61/100'}],
#   'Metascore': '61',
#   'imdbRating': '7.1',
#   'imdbVotes': '20,692',
#   'imdbID': 'tt0070903',
#   'Type': 'movie',
#   'DVD': '22 May 2001',
#   'BoxOffice': 'N/A',
#   'Production': 'Sony Pictures Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Weather Underground',
#   'Year': '2002',
#   'Rated': 'Unrated',
#   'Released': '13 Nov 2003',
#   'Runtime': '92 min',
#   'Genre': 'Documentary, History, War',
#   'Director': 'Sam Green, Bill Siegel(co-director)',
#   'Writer': 'N/A',
#   'Actors': 'Lili Taylor, Pamela Z, Jim Lange, Evan White',
#   'Plot': 'The remarkable story of The Weather Underground, radical activists of the 1970s, and of radical politics at its best and most disastrous.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 4 wins & 3 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI2MTU5Njc3M15BMl5BanBnXkFtZTcwNzA2NzUyMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Metascore': '77',
#   'imdbRating': '7.5',
#   'imdbVotes': '3,313',
#   'imdbID': 'tt0343168',
#   'Type': 'movie',
#   'DVD': '25 May 2004',
#   'BoxOffice': 'N/A',
#   'Production': 'Indican Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wedding Banquet',
#   'Year': '1993',
#   'Rated': 'R',
#   'Released': '04 Aug 1993',
#   'Runtime': '106 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Ang Lee',
#   'Writer': 'Ang Lee, Neil Peng, James Schamus',
#   'Actors': 'Ah-Lei Gua, Sihung Lung, May Chin, Winston Chao',
#   'Plot': 'To satisfy his nagging parents, a gay landlord and a female tenant agree to a marriage of convenience, but his parents arrive to visit and things get out of hand.',
#   'Language': 'Mandarin, English',
#   'Country': 'Taiwan, USA',
#   'Awards': 'Nominated for 1 Oscar. Another 12 wins & 9 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI1NDg2MTQxN15BMl5BanBnXkFtZTcwNTYwNTc3NA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '12,889',
#   'imdbID': 'tt0107156',
#   'Type': 'movie',
#   'DVD': '15 Jun 2004',
#   'BoxOffice': 'N/A',
#   'Production': 'Good Machine',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Well',
#   'Year': '1951',
#   'Rated': 'APPROVED',
#   'Released': '10 Sep 1951',
#   'Runtime': '86 min',
#   'Genre': 'Drama, Film-Noir, Thriller',
#   'Director': 'Leo C. Popkin, Russell Rouse',
#   'Writer': 'Russell Rouse (written for the screen by), Clarence Greene (written for the screen by)',
#   'Actors': 'Gwendolyn Laster, Richard Rober, Maidie Norman, George Hamilton',
#   'Plot': 'A small, racially mixed American town succumbs to violence and utter mayhem after a white man, who is suspected of kidnapping a missing black girl, is released by the white authority.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzOTU3OTA0Nl5BMl5BanBnXkFtZTYwMjI3OTU5._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.3',
#   'imdbVotes': '486',
#   'imdbID': 'tt0044202',
#   'Type': 'movie',
#   'DVD': '20 Feb 2007',
#   'BoxOffice': 'N/A',
#   'Production': 'United Artists',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The West Point Story',
#   'Year': '1950',
#   'Rated': 'APPROVED',
#   'Released': '25 Nov 1950',
#   'Runtime': '107 min',
#   'Genre': 'Comedy, Music',
#   'Director': 'Roy Del Ruth',
#   'Writer': 'John Monks Jr. (screenplay), Charles Hoffman (screenplay), Irving Wallace (screenplay), Irving Wallace (from a story by)',
#   'Actors': 'James Cagney, Virginia Mayo, Doris Day, Gordon MacRae',
#   'Plot': 'A Broadway director helps the West Point cadets put on a show, aided by two lovely ladies and assorted complications.',
#   'Language': 'English, French',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyMTMxNjExM15BMl5BanBnXkFtZTgwNzg4NzEyMjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.2',
#   'imdbVotes': '954',
#   'imdbID': 'tt0043123',
#   'Type': 'movie',
#   'DVD': '24 Apr 2007',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Westerner',
#   'Year': '1940',
#   'Rated': 'Approved',
#   'Released': '20 Sep 1940',
#   'Runtime': '100 min',
#   'Genre': 'Drama, Romance, Western',
#   'Director': 'William Wyler',
#   'Writer': 'Jo Swerling (screenplay), Niven Busch (screenplay), Stuart N. Lake (from the story by)',
#   'Actors': 'Gary Cooper, Walter Brennan, Doris Davenport, Fred Stone',
#   'Plot': "Judge Roy Bean, a self-appointed hanging judge in Vinegarroon, Texas, befriends saddle tramp Cole Harden, who opposes Bean's policy against homesteaders.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 1 win & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjczNDIyYjEtYjgwYS00YTRmLTkxYzgtYjIwZDMwNWE1N2JlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Metascore': '78',
#   'imdbRating': '7.4',
#   'imdbVotes': '4,551',
#   'imdbID': 'tt0033253',
#   'Type': 'movie',
#   'DVD': '29 Sep 1998',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wetback Hound',
#   'Year': '1957',
#   'Rated': 'N/A',
#   'Released': '19 Jun 1957',
#   'Runtime': '18 min',
#   'Genre': 'Short, Family',
#   'Director': 'Janet Lansburgh, Larry Lansburgh',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'Paco, a hound of exceptional heritage, is easily distracted by other animals while on the hunt.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.1',
#   'imdbVotes': '24',
#   'imdbID': 'tt0051187',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The White Cliffs of Dover',
#   'Year': '1944',
#   'Rated': 'Passed',
#   'Released': '01 Jun 1944',
#   'Runtime': '126 min',
#   'Genre': 'Drama, Romance, War',
#   'Director': 'Clarence Brown',
#   'Writer': 'Alice Duer Miller (poem), Claudine West (screenplay), Jan Lustig (screenplay), George Froeschel (screenplay), Robert Nathan (additional poetry)',
#   'Actors': 'Irene Dunne, Alan Marshal, Roddy McDowall, Frank Morgan',
#   'Plot': 'London based American nurse, Susan, Lady Ashwood, is at a hospital awaiting the imminent arrival of wounded soldiers. She is hoping that her enlisted son, Sir John Ashwood, who resembles ...',
#   'Language': 'English, French, German',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYzBmMTc5N2EtYjZhNy00YTI2LTkyYTctNjZiM2M1NWQ2ZjBjXkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '80%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.0',
#   'imdbVotes': '1,311',
#   'imdbID': 'tt0037462',
#   'Type': 'movie',
#   'DVD': '28 Apr 1993',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The White Helmets',
#   'Year': '2016',
#   'Rated': 'TV-14',
#   'Released': '16 Sep 2016',
#   'Runtime': '41 min',
#   'Genre': 'Documentary, Short, Crime, War',
#   'Director': 'Orlando von Einsiedel',
#   'Writer': 'N/A',
#   'Actors': 'Khalid Farah, Mohammed Farah, Abu Omar, Raed Saleh',
#   'Plot': 'As daily airstrikes pound civilian targets in Syria, a group of indomitable first responders risk their lives to rescue victims from the rubble.',
#   'Language': 'Arabic, English',
#   'Country': 'UK',
#   'Awards': 'Won 1 Oscar. Another 2 wins & 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzE4ZTQ3M2YtYjY4ZS00OWNhLWFkYjgtNWIyNzkyOWQ5MGE1XkEyXkFqcGdeQXVyMjMwNjUwMTc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.5',
#   'imdbVotes': '6,256',
#   'imdbID': 'tt6073176',
#   'Type': 'movie',
#   'DVD': '16 Sep 2016',
#   'BoxOffice': 'N/A',
#   'Production': 'Grain Media',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The White Parade',
#   'Year': '1934',
#   'Rated': 'APPROVED',
#   'Released': '16 Nov 1934',
#   'Runtime': '80 min',
#   'Genre': 'Drama',
#   'Director': 'Irving Cummings',
#   'Writer': 'Rian James (screenplay), Jesse Lasky Jr. (screenplay), Rian James (based on a novel by), Sonya Levien (adaptation), Ernest Pascal (adaptation)',
#   'Actors': 'Loretta Young, John Boles, Dorothy Wilson, Muriel Kirkland',
#   'Plot': 'The title represents the hopeful, ambitious students at a hospital training school and is primarily a story of the stern discipline and laborious physical and mental toil they endure in ...',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc1MzEwODkzMV5BMl5BanBnXkFtZTgwMjUzOTU0MjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '50%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.0',
#   'imdbVotes': '42',
#   'imdbID': 'tt0025986',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The White Ribbon',
#   'Year': '2009',
#   'Rated': 'R',
#   'Released': '05 Mar 2010',
#   'Runtime': '144 min',
#   'Genre': 'Drama, History, Mystery, Thriller',
#   'Director': 'Michael Haneke',
#   'Writer': 'Michael Haneke, Michael Haneke (story)',
#   'Actors': 'Christian Friedel, Ernst Jacobi, Leonie Benesch, Ulrich Tukur',
#   'Plot': 'Strange events happen in a small village in the north of Germany during the years before World War I, which seem to be ritual punishment. Who is responsible?',
#   'Language': 'German, Italian, Polish',
#   'Country': 'Germany, Austria, France, Italy, Canada',
#   'Awards': 'Nominated for 2 Oscars. Another 58 wins & 39 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2OTYyNzUxOF5BMl5BanBnXkFtZTcwMzUwMDY4Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#    {'Source': 'Metacritic', 'Value': '82/100'}],
#   'Metascore': '82',
#   'imdbRating': '7.8',
#   'imdbVotes': '64,112',
#   'imdbID': 'tt1149362',
#   'Type': 'movie',
#   'DVD': '29 Jun 2010',
#   'BoxOffice': '$2,077,054',
#   'Production': 'Sony Pictures Classics',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wild Bunch',
#   'Year': '1969',
#   'Rated': 'R',
#   'Released': '19 Jun 1969',
#   'Runtime': '135 min',
#   'Genre': 'Action, Adventure, Western',
#   'Director': 'Sam Peckinpah',
#   'Writer': 'Walon Green (screenplay), Sam Peckinpah (screenplay), Walon Green (story), Roy N. Sickner (story)',
#   'Actors': "William Holden, Ernest Borgnine, Robert Ryan, Edmond O'Brien",
#   'Plot': 'An aging group of outlaws look for one last big score as the "traditional" American West is disappearing around them.',
#   'Language': 'English, Spanish, German',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 5 wins & 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNGUyYTZmOWItMDJhMi00N2IxLWIyNDMtNjUxM2ZiYmU5YWU1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '95/100'}],
#   'Metascore': '95',
#   'imdbRating': '7.9',
#   'imdbVotes': '73,281',
#   'imdbID': 'tt0065214',
#   'Type': 'movie',
#   'DVD': '27 Aug 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wild Bunch: An Album in Montage',
#   'Year': '1996',
#   'Rated': 'N/A',
#   'Released': '01 Nov 1996',
#   'Runtime': '34 min',
#   'Genre': 'Documentary, Short',
#   'Director': 'Paul Seydor',
#   'Writer': 'N/A',
#   'Actors': "Nick Redman, Walon Green, Newell Alexander, Edmond O'Brien",
#   'Plot': 'N/A',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win & 1 nomination.',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.2',
#   'imdbVotes': '220',
#   'imdbID': 'tt0118167',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wild Thornberrys Movie',
#   'Year': '2002',
#   'Rated': 'PG',
#   'Released': '20 Dec 2002',
#   'Runtime': '85 min',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#   'Director': 'Cathy Malkasian, Jeff McGrath',
#   'Writer': 'Arlene Klasky (characters), Gabor Csupo (characters), Steve Pepoon (characters), David Silverman (characters), Stephen Sustarsic (characters), Kate Boutilier',
#   'Actors': 'Lacey Chabert, Tom Kane, Cree Summer, Tim Curry',
#   'Plot': "Eliza and Debbie are two sisters who don't always get along. But their relationship is put to the test when Debbie's life is in danger, and Eliza might have to give up her power to talk to animals....",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 12 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwOTAxODc4NV5BMl5BanBnXkFtZTYwMTU3MTY3._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#    {'Source': 'Metacritic', 'Value': '69/100'}],
#   'Metascore': '69',
#   'imdbRating': '5.6',
#   'imdbVotes': '13,567',
#   'imdbID': 'tt0282120',
#   'Type': 'movie',
#   'DVD': '01 Apr 2003',
#   'BoxOffice': '$39,766,440',
#   'Production': 'Paramount Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wild and the Brave',
#   'Year': '1974',
#   'Rated': 'R',
#   'Released': '15 May 1974',
#   'Runtime': '102 min',
#   'Genre': 'Documentary',
#   'Director': 'Eugene S. Jones',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'This informative program looks at the conflicts that arise when a black man replaces a white chief warden in Uganda.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 nomination.',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '4.0',
#   'imdbVotes': '8',
#   'imdbID': 'tt0072333',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wildest Show in the South: The Angola Prison Rodeo',
#   'Year': '1999',
#   'Rated': 'N/A',
#   'Released': 'N/A',
#   'Runtime': '30 min',
#   'Genre': 'Documentary, Short, Sport',
#   'Director': 'Simeon Soffer',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'N/A',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 2 wins.',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.5',
#   'imdbVotes': '53',
#   'imdbID': 'tt0240216',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wind Rises',
#   'Year': '2013',
#   'Rated': 'PG-13',
#   'Released': '21 Feb 2014',
#   'Runtime': '126 min',
#   'Genre': 'Animation, Biography, Drama, History, Romance, War',
#   'Director': 'Hayao Miyazaki',
#   'Writer': 'Hayao Miyazaki (comic), Hayao Miyazaki (screenplay)',
#   'Actors': 'Hideaki Anno, Hidetoshi Nishijima, Miori Takimoto, Masahiko Nishimura',
#   'Plot': 'A look at the life of Jiro Horikoshi, the man who designed Japanese fighter planes during World War II.',
#   'Language': 'Japanese, German, Italian, French',
#   'Country': 'Japan',
#   'Awards': 'Nominated for 1 Oscar. Another 26 wins & 52 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU4NDg0MzkzNV5BMl5BanBnXkFtZTgwODA3Mzc1MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#    {'Source': 'Metacritic', 'Value': '83/100'}],
#   'Metascore': '83',
#   'imdbRating': '7.8',
#   'imdbVotes': '62,784',
#   'imdbID': 'tt2013293',
#   'Type': 'movie',
#   'DVD': '17 Nov 2014',
#   'BoxOffice': 'N/A',
#   'Production': 'Walt Disney Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wind and the Lion',
#   'Year': '1975',
#   'Rated': 'PG',
#   'Released': '26 Jun 1975',
#   'Runtime': '119 min',
#   'Genre': 'Action, Adventure, Drama',
#   'Director': 'John Milius',
#   'Writer': 'John Milius',
#   'Actors': 'Sean Connery, Candice Bergen, Brian Keith, John Huston',
#   'Plot': 'In early twentieth century Morocco, a Sharif kidnaps an American woman and her children, forcing President Theodore Roosevelt to send in forces to conduct a rescue mission.',
#   'Language': 'English, German, French',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYTNhODI4NWYtYzc1Zi00OGIxLTk5ZWUtOTA0MDZkNDM2OTA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '64%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.9',
#   'imdbVotes': '7,644',
#   'imdbID': 'tt0073906',
#   'Type': 'movie',
#   'DVD': '06 Jan 2004',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Window',
#   'Year': '1949',
#   'Rated': 'Approved',
#   'Released': '01 May 1949',
#   'Runtime': '73 min',
#   'Genre': 'Drama, Film-Noir, Thriller',
#   'Director': 'Ted Tetzlaff',
#   'Writer': 'Mel Dinelli (screenplay), Cornell Woolrich (based on a story by: "The Boy Cried Murder")',
#   'Actors': 'Barbara Hale, Arthur Kennedy, Paul Stewart, Ruth Roman',
#   'Plot': 'To avoid the heat of a sweltering summer night a 9-year-old Manhattan boy decides to sleep on the fire escape and witnesses a murder, but no one will believe him.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win & 2 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZDUxOTIyZWMtMDM1MS00ZWE2LTg0MDktZjFmYmNlM2I4MmRiXkEyXkFqcGdeQXVyMTYzMTY1MjQ@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.4',
#   'imdbVotes': '3,031',
#   'imdbID': 'tt0042046',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'RKO Radio Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wings of the Dove',
#   'Year': '1997',
#   'Rated': 'R',
#   'Released': '13 Mar 1998',
#   'Runtime': '102 min',
#   'Genre': 'Drama, Romance',
#   'Director': 'Iain Softley',
#   'Writer': 'Henry James (novel), Hossein Amini (screenplay)',
#   'Actors': 'Helena Bonham Carter, Linus Roache, Alex Jennings, Charlotte Rampling',
#   'Plot': 'An impoverished woman who has been forced to choose between a privileged life with her wealthy aunt and her journalist lover, befriends an American heiress. When she discovers the heiress is attracted to her own lover and is dying, she sees a chance to have both the privileged life she cannot give up and the lover she cannot live without.',
#   'Language': 'English',
#   'Country': 'USA, UK',
#   'Awards': 'Nominated for 4 Oscars. Another 16 wins & 28 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMGY5ZmZiOTgtMWEzYS00NmNkLTk2MTUtNTg3YjliNDg0NmUzXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#    {'Source': 'Metacritic', 'Value': '73/100'}],
#   'Metascore': '73',
#   'imdbRating': '7.1',
#   'imdbVotes': '9,951',
#   'imdbID': 'tt0120520',
#   'Type': 'movie',
#   'DVD': '14 Sep 1999',
#   'BoxOffice': 'N/A',
#   'Production': 'Miramax',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Winning Strain',
#   'Year': '1966',
#   'Rated': 'N/A',
#   'Released': 'N/A',
#   'Runtime': 'N/A',
#   'Genre': 'Short',
#   'Director': 'N/A',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'N/A',
#   'Language': 'N/A',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.4',
#   'imdbVotes': '5',
#   'imdbID': 'tt0061200',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Witches of Eastwick',
#   'Year': '1987',
#   'Rated': 'R',
#   'Released': '12 Jun 1987',
#   'Runtime': '118 min',
#   'Genre': 'Comedy, Fantasy, Horror',
#   'Director': 'George Miller',
#   'Writer': 'John Updike (novel), Michael Cristofer (screenplay)',
#   'Actors': 'Jack Nicholson, Cher, Susan Sarandon, Michelle Pfeiffer',
#   'Plot': 'Three single women in a picturesque village have their wishes granted, at a cost, when a mysterious and flamboyant man arrives in their lives.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 5 wins & 10 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYTA4ZGRlNDEtNDliMi00NmI0LThlYjctYmViMjI0MDlmOWU2XkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Metascore': '67',
#   'imdbRating': '6.5',
#   'imdbVotes': '57,721',
#   'imdbID': 'tt0094332',
#   'Type': 'movie',
#   'DVD': '27 Aug 1997',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Witness from the Balcony of Room 306',
#   'Year': '2008',
#   'Rated': 'N/A',
#   'Released': '18 Feb 2009',
#   'Runtime': '32 min',
#   'Genre': 'Documentary, Short',
#   'Director': 'Adam Pertofsky',
#   'Writer': 'N/A',
#   'Actors': 'Benjamin Hooks, Samuel Kyles, Maxine Smith',
#   'Plot': 'On April 4,1968, the Revered Samuel "Billy" Kyles stood beside Dr. Martin Luther King, Jr. on the balcony of the Lorraine Motel in Memphis, Tennessee and bore witness to his brutal assassination. Through Rev. Kyles\' recollect',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 5 wins & 1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MDE2MjM0Nl5BMl5BanBnXkFtZTgwNTgyMTAzMjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '8.1',
#   'imdbVotes': '44',
#   'imdbID': 'tt1360068',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'Rock Paper Scissors',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wiz',
#   'Year': '1978',
#   'Rated': 'G',
#   'Released': '24 Oct 1978',
#   'Runtime': '134 min',
#   'Genre': 'Adventure, Family, Fantasy, Musical',
#   'Director': 'Sidney Lumet',
#   'Writer': 'L. Frank Baum (novel), William F. Brown (book), Joel Schumacher (screenplay)',
#   'Actors': 'Diana Ross, Michael Jackson, Nipsey Russell, Ted Ross',
#   'Plot': 'An adaptation of "The Wizard of Oz" that tries to capture the essence of the African-American experience.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 4 Oscars. Another 1 win & 7 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzU0YzkzYjItOThjNi00NTU4LWIxZDEtN2U4NmFkMGFiOWI3XkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '42%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.4',
#   'imdbVotes': '12,909',
#   'imdbID': 'tt0078504',
#   'Type': 'movie',
#   'DVD': '13 Apr 1999',
#   'BoxOffice': 'N/A',
#   'Production': 'Universal Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wizard of Oz',
#   'Year': '1939',
#   'Rated': 'PG',
#   'Released': '25 Aug 1939',
#   'Runtime': '102 min',
#   'Genre': 'Adventure, Family, Fantasy, Musical',
#   'Director': 'Victor Fleming, George Cukor, Mervyn LeRoy, Norman Taurog, Richard Thorpe, King Vidor',
#   'Writer': 'Noel Langley (screenplay), Florence Ryerson (screenplay), Edgar Allan Woolf (screenplay), Noel Langley (adaptation), L. Frank Baum (from the book by)',
#   'Actors': 'Judy Garland, Frank Morgan, Ray Bolger, Bert Lahr',
#   'Plot': 'Dorothy Gale is swept away from a farm in Kansas to a magical land of Oz in a tornado and embarks on a quest with her new friends to see the Wizard who can help her return home to Kansas and help her friends as well.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 2 Oscars. Another 7 wins & 14 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjUyMTc4MDExMV5BMl5BanBnXkFtZTgwNDg0NDIwMjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#    {'Source': 'Metacritic', 'Value': '100/100'}],
#   'Metascore': '100',
#   'imdbRating': '8.0',
#   'imdbVotes': '356,401',
#   'imdbID': 'tt0032138',
#   'Type': 'movie',
#   'DVD': '19 Oct 1999',
#   'BoxOffice': '$3,840,702',
#   'Production': 'Warner Bros. Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wizard of the Strings',
#   'Year': '1985',
#   'Rated': 'N/A',
#   'Released': 'N/A',
#   'Runtime': '27 min',
#   'Genre': 'Documentary, Short, Biography',
#   'Director': 'Peter Friedman',
#   'Writer': 'N/A',
#   'Actors': 'Roy Smeck',
#   'Plot': 'Profiles Roy Smeck, a former vaudeville star known as "The Wizard of the Strings" because of his virtuoso talents on the guitar, banjo, ukelele and Hawaiian guitar, and who is shown to be ...',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win.',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.9',
#   'imdbVotes': '16',
#   'imdbID': 'tt0090332',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wolf Men',
#   'Year': '1969',
#   'Rated': 'N/A',
#   'Released': 'N/A',
#   'Runtime': 'N/A',
#   'Genre': 'Documentary',
#   'Director': 'N/A',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'N/A',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.4',
#   'imdbVotes': '7',
#   'imdbID': 'tt0065220',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wolf of Wall Street',
#   'Year': '2013',
#   'Rated': 'R',
#   'Released': '25 Dec 2013',
#   'Runtime': '180 min',
#   'Genre': 'Biography, Crime, Drama',
#   'Director': 'Martin Scorsese',
#   'Writer': 'Terence Winter (screenplay), Jordan Belfort (book)',
#   'Actors': 'Leonardo DiCaprio, Jonah Hill, Margot Robbie, Matthew McConaughey',
#   'Plot': 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#   'Language': 'English, French',
#   'Country': 'USA',
#   'Awards': 'Nominated for 5 Oscars. Another 38 wins & 165 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIxMjgxNTk0MF5BMl5BanBnXkFtZTgwNjIyOTg2MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Metascore': '75',
#   'imdbRating': '8.2',
#   'imdbVotes': '1,069,666',
#   'imdbID': 'tt0993846',
#   'Type': 'movie',
#   'DVD': '25 Mar 2014',
#   'BoxOffice': '$91,330,760',
#   'Production': 'Paramount Studios',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wolfman',
#   'Year': '2010',
#   'Rated': 'R',
#   'Released': '12 Feb 2010',
#   'Runtime': '103 min',
#   'Genre': 'Drama, Fantasy, Horror, Thriller',
#   'Director': 'Joe Johnston',
#   'Writer': 'Andrew Kevin Walker (screenplay), David Self (screenplay), Curt Siodmak',
#   'Actors': 'Simon Merrells, Gemma Whelan, Emily Blunt, Benicio Del Toro',
#   'Plot': 'Upon his return to his ancestral homeland, an American man is bitten, and subsequently cursed by, a werewolf.',
#   'Language': 'English, Romany, Romanian, Ukrainian',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 3 wins & 8 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTUyODEyMDIyM15BMl5BanBnXkFtZTcwNTYxMzg5Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#    {'Source': 'Metacritic', 'Value': '43/100'}],
#   'Metascore': '43',
#   'imdbRating': '5.8',
#   'imdbVotes': '99,351',
#   'imdbID': 'tt0780653',
#   'Type': 'movie',
#   'DVD': '01 Jun 2010',
#   'BoxOffice': '$61,937,495',
#   'Production': 'Universal Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Woman in Red',
#   'Year': '1984',
#   'Rated': 'PG-13',
#   'Released': '15 Aug 1984',
#   'Runtime': '87 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Gene Wilder',
#   'Writer': 'Jean-Loup Dabadie (screenplay "Un Elephant Ca Trompe Enormement"), Yves Robert (screenplay "Un Elephant Ca Trompe Enormement"), Gene Wilder',
#   'Actors': 'Gene Wilder, Charles Grodin, Joseph Bologna, Judith Ivey',
#   'Plot': 'On his way to work, Teddy spots Charlotte, an incredibly beautiful Woman in Red. He really wants to meet her, but what would his wife say?',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 1 win & 1 nomination.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjI5YzczYzAtZTY5Yy00YjMyLTkwNzgtNjY5ZTkwYjdjNjhlXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#    {'Source': 'Metacritic', 'Value': '55/100'}],
#   'Metascore': '55',
#   'imdbRating': '5.9',
#   'imdbVotes': '12,918',
#   'imdbID': 'tt0088414',
#   'Type': 'movie',
#   'DVD': '07 Jan 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Orion Pictures Corporation',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Woman in the Window',
#   'Year': '1944',
#   'Rated': 'Approved',
#   'Released': '03 Nov 1944',
#   'Runtime': '107 min',
#   'Genre': 'Crime, Drama, Film-Noir, Mystery, Thriller',
#   'Director': 'Fritz Lang',
#   'Writer': 'Nunnally Johnson (written for the screen by), J.H. Wallis (novel)',
#   'Actors': 'Edward G. Robinson, Joan Bennett, Raymond Massey, Edmund Breon',
#   'Plot': 'When a conservative middle-aged professor engages in a minor dalliance with a femme fatale, he is plunged into a nightmarish quicksand of blackmail and murder.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMGUxNTljMzUtNjA1Zi00YTE3LTlmMWMtNzlmNjEyM2Q1NWMxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '12,320',
#   'imdbID': 'tt0037469',
#   'Type': 'movie',
#   'DVD': '10 Jul 2007',
#   'BoxOffice': 'N/A',
#   'Production': 'International Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Wonderful World of the Brothers Grimm',
#   'Year': '1962',
#   'Rated': 'G',
#   'Released': '16 Jul 1963',
#   'Runtime': '135 min',
#   'Genre': 'Animation, Adventure, Biography, Comedy, Drama, Family, Fantasy, Musical, Romance',
#   'Director': 'Henry Levin, George Pal',
#   'Writer': 'David P. Harmon (screenplay), Charles Beaumont (screenplay), William Roberts (screenplay), David P. Harmon (story), Hermann Gerstner (based on "Die Bruder Grimm")',
#   'Actors': 'Laurence Harvey, Karlheinz Böhm, Claire Bloom, Walter Slezak',
#   'Plot': 'The story of Wilhelm and Jacob Grimm, and three of their stories...',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 1 win & 7 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTlhMmZlNmMtOWQ5NS00YzNhLWIxMDEtOTA5OGYxYzkwZjhlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.4',
#   'imdbVotes': '1,339',
#   'imdbID': 'tt0056700',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Word',
#   'Year': '1953',
#   'Rated': 'N/A',
#   'Released': 'N/A',
#   'Runtime': 'N/A',
#   'Genre': 'Documentary, Short',
#   'Director': 'N/A',
#   'Writer': 'N/A',
#   'Actors': 'N/A',
#   'Plot': 'N/A',
#   'Language': 'N/A',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [],
#   'Metascore': 'N/A',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'imdbID': 'tt0046559',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'The Wrong Trousers',
#   'Year': '1993',
#   'Rated': 'Not Rated',
#   'Released': '17 Dec 1993',
#   'Runtime': '30 min',
#   'Genre': 'Animation, Short, Comedy, Crime, Family, Sci-Fi',
#   'Director': 'Nick Park',
#   'Writer': 'Nick Park, Bob Baker, Brian Sibley (additional contributions by), Nick Park (characters), Brian Trueman (based on the story by), Jonathan Trueman (based on the story by)',
#   'Actors': 'Peter Sallis',
#   'Plot': 'Wallace takes in a new lodger, a devious penguin. Sporting some techno-trousers, the penguin plans a grand theft, a plan that involves putting Wallace in danger.',
#   'Language': 'English',
#   'Country': 'UK',
#   'Awards': 'Won 1 Oscar. Another 12 wins.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDBmNGU4MTEtMmI2Mi00NjU1LTgxNTktMDQ1MDE0Y2MwMjYwXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '8.3',
#   'imdbVotes': '48,112',
#   'imdbID': 'tt0108598',
#   'Type': 'movie',
#   'DVD': '01 Aug 1995',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Yanks Are Coming',
#   'Year': '1963',
#   'Rated': 'N/A',
#   'Released': '04 Nov 1963',
#   'Runtime': '45 min',
#   'Genre': 'Documentary',
#   'Director': 'N/A',
#   'Writer': 'N/A',
#   'Actors': 'Richard Basehart',
#   'Plot': 'A documentary--nominated for an Academy Award--about the American involvement in World War I.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '4.7',
#   'imdbVotes': '6',
#   'imdbID': 'tt0057698',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Yearling',
#   'Year': '1946',
#   'Rated': 'Approved',
#   'Released': '01 May 1947',
#   'Runtime': '128 min',
#   'Genre': 'Drama, Family, Western',
#   'Director': 'Clarence Brown',
#   'Writer': 'Paul Osborn (screen play), Marjorie Kinnan Rawlings (based on the Pulitzer Prize novel by)',
#   'Actors': 'Gregory Peck, Jane Wyman, Claude Jarman Jr., Chill Wills',
#   'Plot': 'A boy persuades his parents to allow him to adopt a young deer, but what will happen if the deer misbehaves?',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 2 Oscars. Another 1 win & 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0NjVhMDMtZTZmMy00MWYwLTkyMjQtMDEyMmVkYmJmOTQ5XkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#    {'Source': 'Metacritic', 'Value': '89/100'}],
#   'Metascore': '89',
#   'imdbRating': '7.2',
#   'imdbVotes': '4,997',
#   'imdbID': 'tt0039111',
#   'Type': 'movie',
#   'DVD': '03 Sep 2002',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'The Young Girls of Rochefort',
#   'Year': '1967',
#   'Rated': 'G',
#   'Released': '11 Apr 1968',
#   'Runtime': '125 min',
#   'Genre': 'Comedy, Drama, Musical, Romance',
#   'Director': 'Jacques Demy',
#   'Writer': 'Jacques Demy',
#   'Actors': 'Catherine Deneuve, George Chakiris, Françoise Dorléac, Jacques Perrin',
#   'Plot': 'Two sisters leave their small seaside town of Rochefort in search of romance. Hired as carnival singers, one falls for an American musician, while the other must search for her ideal partner.',
#   'Language': 'French, English',
#   'Country': 'France',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZmFmZThkYjQtMTQ5Zi00YmQ4LTlmZmMtNTZiNDhhOTI4NjBmXkEyXkFqcGdeQXVyNjMwMjk0MTQ@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '98%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.6',
#   'imdbVotes': '7,265',
#   'imdbID': 'tt0062873',
#   'Type': 'movie',
#   'DVD': '22 Jan 2002',
#   'BoxOffice': 'N/A',
#   'Production': 'Miramax-Zoe',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Young Land',
#   'Year': '1959',
#   'Rated': 'Approved',
#   'Released': '01 May 1959',
#   'Runtime': '89 min',
#   'Genre': 'Adventure, Drama, History, Romance, Western',
#   'Director': 'Ted Tetzlaff',
#   'Writer': 'Norman S. Hall (screenplay), John Reese (story "Frontier Frenzy")',
#   'Actors': "Patrick Wayne, Yvonne Craig, Dennis Hopper, Dan O'Herlihy",
#   'Plot': 'An American gunslinger kills a Mexican man in California immediately after the Mexican-American war. The killer is arrested and put on trial for murder with the Hispanic population waiting to learn of American justice.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZGY0NTU1NmQtYmQ0NS00ZmM3LWEwNzgtOTVjMGM0OWY0Zjk5XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.5',
#   'imdbVotes': '209',
#   'imdbID': 'tt0053461',
#   'Type': 'movie',
#   'DVD': '08 Mar 2005',
#   'BoxOffice': 'N/A',
#   'Production': 'Columbia Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Young Lions',
#   'Year': '1958',
#   'Rated': 'Approved',
#   'Released': '02 Apr 1958',
#   'Runtime': '167 min',
#   'Genre': 'Action, Drama, War',
#   'Director': 'Edward Dmytryk',
#   'Writer': 'Edward Anhalt (screenplay), Irwin Shaw (novel)',
#   'Actors': 'Marlon Brando, Montgomery Clift, Dean Martin, Hope Lange',
#   'Plot': 'WW2 drama that follows the lives of three young men, one German and two Americans, during wartime.',
#   'Language': 'English, French, German',
#   'Country': 'USA',
#   'Awards': 'Nominated for 3 Oscars. Another 1 win & 4 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYmMwZjQ4NzYtYzAzNC00Yjg0LWJhZWEtMTg5NzA4ZmZmOTI2XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '83%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.2',
#   'imdbVotes': '6,807',
#   'imdbID': 'tt0052415',
#   'Type': 'movie',
#   'DVD': '06 Nov 2001',
#   'BoxOffice': 'N/A',
# ...
#   'Actors': "John Hubbard, Martha O'Driscoll, Richard Beavers, Ruth Terry",
#   'Plot': 'Youth on Parade',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNjE0NTUwNF5BMl5BanBnXkFtZTcwNDQwMDc1NQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '5.6',
#   'imdbVotes': '23',
#   'imdbID': 'tt0035587',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Z',
#   'Year': '1969',
#   'Rated': 'M/PG',
#   'Released': '08 Dec 1969',
#   'Runtime': '127 min',
#   'Genre': 'Crime, Drama, History, Thriller',
#   'Director': 'Costa-Gavras',
#   'Writer': 'Vasilis Vasilikos (novel), Jorge Semprún (dialogue)',
#   'Actors': 'Yves Montand, Irene Papas, Jean-Louis Trintignant, François Périer',
#   'Plot': 'Following the murder of a prominent leftist, an investigator tries to uncover the truth while government officials attempt to cover up their roles.',
#   'Language': 'French, Russian, English',
#   'Country': 'France, Algeria',
#   'Awards': 'Won 2 Oscars. Another 9 wins & 12 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BM2JjM2MwMDAtNGRhMi00MDZiLWIwMzYtYTZmMTc0MDU1ZWU5XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '8.3',
#   'imdbVotes': '21,721',
#   'imdbID': 'tt0065234',
#   'Type': 'movie',
#   'DVD': '02 Jul 2002',
#   'BoxOffice': 'N/A',
#   'Production': 'Rialto Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zelary',
#   'Year': '2003',
#   'Rated': 'R',
#   'Released': '04 Sep 2003',
#   'Runtime': '150 min',
#   'Genre': 'Drama, Romance, War',
#   'Director': 'Ondrej Trojan',
#   'Writer': 'Kveta Legátová (novel), Petr Jarchovský',
#   'Actors': 'Anna Geislerová, György Cserhalmi, Jaroslava Adamová, Miroslav Donutil',
#   'Plot': 'A nurse and her surgeon-lover are part of a resistance movement in 1940s Czechoslovakia. When they are discovered, her lover flees and she must find a place to hide. A patient whose life ...',
#   'Language': 'Czech, Russian, German',
#   'Country': 'Czech Republic, Slovakia, Austria',
#   'Awards': 'Nominated for 1 Oscar. Another 4 wins & 10 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODk2NzU2MDQ5M15BMl5BanBnXkFtZTcwMzM2NjYyMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '7.7',
#   'imdbVotes': '3,155',
#   'imdbID': 'tt0288330',
#   'Type': 'movie',
#   'DVD': '08 Feb 2005',
#   'BoxOffice': 'N/A',
#   'Production': 'Sony Pictures Classics',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zelig',
#   'Year': '1983',
#   'Rated': 'PG',
#   'Released': '25 Aug 1983',
#   'Runtime': '79 min',
#   'Genre': 'Comedy',
#   'Director': 'Woody Allen',
#   'Writer': 'Woody Allen',
#   'Actors': 'Woody Allen, Mia Farrow, Patrick Horgan, John Buckwalter',
#   'Plot': '"Documentary" about a man who can look and act like whoever he\'s around, and meets various famous people.',
#   'Language': 'English, German',
#   'Country': 'USA',
#   'Awards': 'Nominated for 2 Oscars. Another 6 wins & 14 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMGUwMjM0MTEtOGY2NS00MjJmLWEyMDAtYmNkMWJjOWJlNGM0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '37,660',
#   'imdbID': 'tt0086637',
#   'Type': 'movie',
#   'DVD': '06 Nov 2001',
#   'BoxOffice': 'N/A',
#   'Production': 'Warner Home Video',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zero Dark Thirty',
#   'Year': '2012',
#   'Rated': 'R',
#   'Released': '11 Jan 2013',
#   'Runtime': '157 min',
#   'Genre': 'Drama, Thriller',
#   'Director': 'Kathryn Bigelow',
#   'Writer': 'Mark Boal',
#   'Actors': 'Jason Clarke, Reda Kateb, Jessica Chastain, Kyle Chandler',
#   'Plot': 'A chronicle of the decade-long hunt for al-Qaeda terrorist leader Osama bin Laden after the September 2001 attacks, and his death at the hands of the Navy S.E.A.L.s Team 6 in May 2011.',
#   'Language': 'English, Arabic',
#   'Country': 'USA, United Arab Emirates',
#   'Awards': 'Won 1 Oscar. Another 87 wins & 171 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4OTUyNzcwN15BMl5BanBnXkFtZTcwMTQ1NDE3OA@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '95/100'}],
#   'Metascore': '95',
#   'imdbRating': '7.4',
#   'imdbVotes': '255,941',
#   'imdbID': 'tt1790885',
#   'Type': 'movie',
#   'DVD': '19 Mar 2013',
#   'BoxOffice': '$95,720,716',
#   'Production': 'Columbia Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zootopia',
#   'Year': '2016',
#   'Rated': 'PG',
#   'Released': '04 Mar 2016',
#   'Runtime': '108 min',
#   'Genre': 'Animation, Adventure, Comedy, Crime, Family, Mystery',
#   'Director': 'Byron Howard, Rich Moore, Jared Bush(co-director)',
#   'Writer': 'Byron Howard (story by), Rich Moore (story by), Jared Bush (story by), Jim Reardon (story by), Josie Trinidad (story by), Phil Johnston (story by), Jennifer Lee (story by), Jared Bush (screenplay by), Phil Johnston (screenplay by)',
#   'Actors': 'Ginnifer Goodwin, Jason Bateman, Idris Elba, Jenny Slate',
#   'Plot': 'In a city of anthropomorphic animals, a rookie bunny cop and a cynical con artist fox must work together to uncover a conspiracy.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 45 wins & 65 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Metascore': '78',
#   'imdbRating': '8.0',
#   'imdbVotes': '394,091',
#   'imdbID': 'tt2948356',
#   'Type': 'movie',
#   'DVD': '07 Jun 2016',
#   'BoxOffice': '$341,264,012',
#   'Production': 'Walt Disney Animation Studios',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zorba the Greek',
#   'Year': '1964',
#   'Rated': 'Not Rated',
#   'Released': '14 Dec 1964',
#   'Runtime': '142 min',
#   'Genre': 'Comedy, Drama',
#   'Director': 'Michael Cacoyannis',
#   'Writer': 'Nikos Kazantzakis (from the novel "The Life and Times of Alexis Zorba"), Michael Cacoyannis (screenplay)',
#   'Actors': 'Anthony Quinn, Alan Bates, Irene Papas, Lila Kedrova',
#   'Plot': 'An uptight English writer travelling to Crete, on a matter of business, finds his life changed forever when he meets the gregarious Alexis Zorba.',
#   'Language': 'English, Greek',
#   'Country': 'Greece, USA',
#   'Awards': 'Won 3 Oscars. Another 4 wins & 16 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMDE2NDg5N15BMl5BanBnXkFtZTgwMzY3NjYwMTE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '78%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '19,035',
#   'imdbID': 'tt0057831',
#   'Type': 'movie',
#   'DVD': '03 Aug 2004',
#   'BoxOffice': 'N/A',
#   'Production': 'Fox',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Zus & Zo',
#   'Year': '2001',
#   'Rated': 'Unrated',
#   'Released': '08 May 2002',
#   'Runtime': '106 min',
#   'Genre': 'Comedy, Fantasy, Romance',
#   'Director': 'Paula van der Oest',
#   'Writer': 'Paula van der Oest',
#   'Actors': 'Sylvia Poorta, Anneke Blok, Monic Hendrickx, Jacob Derwig',
#   'Plot': 'Zus & Zo shows what three sisters are willing to do to stop their would-be sister-in-law from coming into possession of Paraíso, their beloved family summer home on the Portuguese coast.',
#   'Language': 'Dutch, English, French, Portuguese',
#   'Country': 'Netherlands',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win & 6 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIxMjQxMzExNl5BMl5BanBnXkFtZTcwMDAyMTcxMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Metascore': '50',
#   'imdbRating': '6.3',
#   'imdbVotes': '1,518',
#   'imdbID': 'tt0245157',
#   'Type': 'movie',
#   'DVD': '08 Jul 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Lifesize Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Images',
#   'Year': '1972',
#   'Rated': 'R',
#   'Released': '18 Dec 1972',
#   'Runtime': '104 min',
#   'Genre': 'Drama, Horror, Mystery',
#   'Director': 'Robert Altman',
#   'Writer': 'Robert Altman, Susannah York (novel)',
#   'Actors': 'Susannah York, Rene Auberjonois, Marcel Bozzuffi, Hugh Millais',
#   'Plot': 'Schizophrenic housewife, engulfed by terrorizing apparitions, kills off each, unknowing if these demons are merely figments of her hallucinatory imagination or part of reality.',
#   'Language': 'English, French',
#   'Country': 'UK, USA',
#   'Awards': 'Nominated for 1 Oscar. Another 1 win & 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjA1OTNhZWUtNjU2ZS00N2FiLTg3MDItYzFiOTZjNWJhNWE4XkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.2',
#   'imdbVotes': '4,442',
#   'imdbID': 'tt0068732',
#   'Type': 'movie',
#   'DVD': '16 Sep 2003',
#   'BoxOffice': 'N/A',
#   'Production': 'Columbia Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Sex, Lies, and Videotape',
#   'Year': '1989',
#   'Rated': 'R',
#   'Released': '22 Sep 1989',
#   'Runtime': '100 min',
#   'Genre': 'Drama',
#   'Director': 'Steven Soderbergh',
#   'Writer': 'Steven Soderbergh',
#   'Actors': 'James Spader, Andie MacDowell, Peter Gallagher, Laura San Giacomo',
#   'Plot': "A sexually repressed woman's husband is having an affair with her sister. The arrival of a visitor with a rather unusual fetish changes everything.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Nominated for 1 Oscar. Another 15 wins & 22 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDllYWVkOTQtZjRlMC00NWFjLWI0OGEtOWY4YzU4ZjMxYzg3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '86/100'}],
#   'Metascore': '86',
#   'imdbRating': '7.2',
#   'imdbVotes': '45,568',
#   'imdbID': 'tt0098724',
#   'Type': 'movie',
#   'DVD': '28 Aug 2001',
#   'BoxOffice': 'N/A',
#   'Production': 'Sony Pictures Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Accountant',
#   'Year': '2001',
#   'Rated': 'TV-14',
#   'Released': '01 Jan 2001',
#   'Runtime': '35 min',
#   'Genre': 'Comedy, Short',
#   'Director': 'Ray McKinnon',
#   'Writer': 'Ray McKinnon',
#   'Actors': 'Ray McKinnon, Walton Goggins, Eddie King, Gary Richardson',
#   'Plot': "The O'Dell farm is on the rocks. A non-traditional accountant comes with a variety of ways to save the farm.",
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 1 Oscar. Another 6 wins.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4NTM5Mzk5MF5BMl5BanBnXkFtZTcwODYzMDU2Mw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.7',
#   'imdbVotes': '850',
#   'imdbID': 'tt0222675',
#   'Type': 'movie',
#   'DVD': '03 Nov 2009',
#   'BoxOffice': 'N/A',
#   'Production': 'Lightyear Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The End',
#   'Year': '1995',
#   'Rated': 'N/A',
#   'Released': '31 Jan 2012',
#   'Runtime': '6 min',
#   'Genre': 'Animation, Short',
#   'Director': 'Chris Landreth',
#   'Writer': 'Chris Landreth, Robin Bargar',
#   'Actors': 'Jeffrey Hirschfield, Gina Clayton, Hannah Kravitz, Vivian Chelette',
#   'Plot': "An animator finds himself trying to explain his (lack of) artistic vision to his creations, who just aren't impressed.",
#   'Language': 'English',
#   'Country': 'Canada',
#   'Awards': 'Nominated for 1 Oscar. Another 2 wins.',
#   'Poster': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.2',
#   'imdbVotes': '201',
#   'imdbID': 'tt0112958',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Tom Thumb',
#   'Year': '1958',
#   'Rated': 'Approved',
#   'Released': '24 Dec 1958',
#   'Runtime': '98 min',
#   'Genre': 'Family, Fantasy, Musical',
#   'Director': 'George Pal',
#   'Writer': 'Ladislas Fodor (screenplay), Jacob Grimm (based on a story from the pen of), Wilhelm Grimm (based on a story from the pen of)',
#   'Actors': 'Russ Tamblyn, Alan Young, June Thorburn, Terry-Thomas',
#   'Plot': 'A boy, no bigger than a thumb, manages to outwit two thieves determined to make a fortune from him.',
#   'Language': 'English',
#   'Country': 'UK, USA',
#   'Awards': 'Won 1 Oscar. Another 5 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTczMzc5OTA4N15BMl5BanBnXkFtZTgwNDgzNjA1MjE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.5',
#   'imdbVotes': '2,114',
#   'imdbID': 'tt0052427',
#   'Type': 'movie',
#   'DVD': '03 Oct 2000',
#   'BoxOffice': 'N/A',
#   'Production': 'MGM Home Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'À Nous la Liberté',
#   'Year': '1931',
#   'Rated': 'Not Rated',
#   'Released': '31 Dec 1931',
#   'Runtime': '97 min',
#   'Genre': 'Comedy, Musical',
#   'Director': 'René Clair',
#   'Writer': 'René Clair (story and screenplay)',
#   'Actors': 'Henri Marchand, Raymond Cordy, Rolla France, Paul Ollivier',
#   'Plot': 'Seeking better life, two convicts escape from prison.',
#   'Language': 'French',
#   'Country': 'France',
#   'Awards': 'Nominated for 1 Oscar. Another 3 wins.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODg0ODAzNTItM2M4ZC00NGYxLWIzMmMtNzFiMWIzYWU2YWJiXkEyXkFqcGdeQXVyMzg1ODEwNQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.6',
#   'imdbVotes': '3,724',
#   'imdbID': 'tt0022599',
#   'Type': 'movie',
#   'DVD': '20 Aug 2002',
#   'BoxOffice': 'N/A',
#   'Production': 'Harold Auten',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Adalen 31',
#   'Year': '1969',
#   'Rated': 'X',
#   'Released': '22 Oct 1969',
#   'Runtime': '110 min',
#   'Genre': 'Drama, History, Romance',
#   'Director': 'Bo Widerberg',
#   'Writer': 'Bo Widerberg',
#   'Actors': 'Peter Schildt, Kerstin Tidelius, Roland Hedlund, Stefan Feierbach',
#   'Plot': 'During a strike strike-breakers are being transported to Lunde, where they are assaulted by the strikers. The military are sent in. On the 14th May 1931 there is a confrontation between ...',
#   'Language': 'Swedish',
#   'Country': 'Sweden',
#   'Awards': 'Nominated for 1 Oscar. Another 6 wins & 3 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTI2MDZkOWItM2Y1NS00ZjZmLWJiZjQtNzE0MzgzMzI4ZTRiXkEyXkFqcGdeQXVyMTMwOTMzNzU@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '7.5',
#   'imdbVotes': '1,109',
#   'imdbID': 'tt0065261',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'}]

# %%
imdb_df = pd.read_csv('imdb.csv')
imdb_df
# Out:
#       Unnamed: 0                                             Actors  \
# 0            0.0                                                NaN
# 1            1.0  Tobias Engel, Sunnyi Melles, Heinz Trixner, Ro...
# 2            2.0  Paul Hogan, Linda Kozlowski, John Meillon, Dav...
# 3            3.0  Dexter Gordon, François Cluzet, Gabrielle Hake...
# 4            4.0                                                NaN
# 5            5.0  Al Pacino, Jack Warden, John Forsythe, Lee Str...
# 6            6.0  Dudley Moore, Julie Andrews, Bo Derek, Robert ...
# 7            7.0  Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...
# 8            8.0  Sergey Makovetskiy, Nikita Mikhalkov, Sergey G...
# 9            9.0  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 10          10.0  Joseph Melito, Bruce Willis, Jon Seda, Michael...
# 11          11.0  Chiwetel Ejiofor, Dwight Henry, Dickie Gravois...
# 12          12.0  James Franco, Kate Mara, Amber Tamblyn, Sean Bott
# 13          13.0  Jane Alden, Don Amendolia, John Bachelder, Lau...
# 14          14.0                                                NaN
# 15          15.0  Melina Abdullah, Michelle Alexander, Cory Book...
# 16          16.0                                                NaN
# 17          17.0  William Daniels, Howard Da Silva, Ken Howard, ...
# 18          18.0  Vladimír Ráz, Václav Voska, Josef Bek, Zdenek ...
# 19          19.0  Dan Aykroyd, Ned Beatty, John Belushi, Lorrain...
# 20          20.0  Lou Adler, Stephanie 'Stevvi' Alexander, Patti...
# 21          21.0  Kirk Douglas, James Mason, Paul Lukas, Peter L...
# 22          22.0  Keir Dullea, Gary Lockwood, William Sylvester,...
# 23          23.0  Roy Scheider, John Lithgow, Helen Mirren, Bob ...
# 24          24.0  Annette Bening, Elle Fanning, Greta Gerwig, Bi...
# 25          25.0  Jack Webb, Art Balinger, Walter Sande, Ralph M...
# 26          26.0                                                NaN
# 27          27.0  Russell Crowe, Christian Bale, Logan Lerman, D...
# 28          28.0  Robert Fleury, Joseph Tul, Osmond Beckwith, Do...
# 29          29.0  Maxine McNair, Chris McNair, Helen Pegues, Que...
# ...          ...                                                ...
# 4470       469.0  Fred Astaire, Rita Hayworth, Robert Benchley, ...
# 4471       470.0  Alice Faye, George Murphy, Ken Murray, Charles...
# 4472       471.0  Diane Adams, Phil Aubry, Nancy Austin, Patrici...
# 4473       472.0  Jean Simmons, Stewart Granger, Deborah Kerr, C...
# 4474       473.0  Gene Wilder, Peter Boyle, Marty Feldman, Madel...
# 4475       474.0  Emilio Estevez, Kiefer Sutherland, Lou Diamond...
# 4476       475.0  Henry Fonda, Alice Brady, Marjorie Weaver, Arl...
# 4477       476.0  Nicholas Rowe, Alan Cox, Sophie Ward, Anthony ...
# 4478       477.0  Robert Shaw, Anne Bancroft, Simon Ward, Jack H...
# 4479       478.0               Louis Gothelf, Reva Shwayder-Gothelf
# 4480       479.0                                  Maureen McElheron
# 4481       480.0                                                NaN
# 4482       481.0  The Retrosettes, Gabriella Belisario, Laura De...
# 4483       482.0                  Lewis B. Hershey, J. Edgar Hoover
# 4484       483.0  John Hubbard, Martha O'Driscoll, Richard Beave...
# 4485       484.0  Yves Montand, Irene Papas, Jean-Louis Trintign...
# 4486       485.0  Anna Geislerová, György Cserhalmi, Jaroslava A...
# 4487       486.0  Woody Allen, Mia Farrow, Patrick Horgan, John ...
# 4488       487.0  Jason Clarke, Reda Kateb, Jessica Chastain, Ky...
# 4489       488.0  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...
# 4490       489.0  Anthony Quinn, Alan Bates, Irene Papas, Lila K...
# 4491       490.0  Sylvia Poorta, Anneke Blok, Monic Hendrickx, J...
# 4492       491.0  Susannah York, Rene Auberjonois, Marcel Bozzuf...
# 4493       492.0  James Spader, Andie MacDowell, Peter Gallagher...
# 4494       493.0  Ray McKinnon, Walton Goggins, Eddie King, Gary...
# 4495       494.0  Jeffrey Hirschfield, Gina Clayton, Hannah Krav...
# 4496       495.0  Russ Tamblyn, Alan Young, June Thorburn, Terry...
# 4497       496.0  Henri Marchand, Raymond Cordy, Rolla France, P...
# 4498       497.0  Peter Schildt, Kerstin Tidelius, Roland Hedlun...
# 4499       498.0                                                NaN
#
#                                                  Awards     BoxOffice  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2     Nominated for 1 Oscar. Another 3 wins & 7 nomi...           NaN
# 3         Won 1 Oscar. Another 9 wins & 11 nominations.           NaN
# 4                                                   NaN           NaN
# 5     Nominated for 2 Oscars. Another 1 win & 1 nomi...           NaN
# 6        Nominated for 2 Oscars. Another 9 nominations.           NaN
# 7     Nominated for 1 Oscar. Another 1 win & 6 nomin...   $65,406,212
# 8     Nominated for 1 Oscar. Another 9 wins & 7 nomi...           NaN
# 9     Nominated for 3 Oscars. Another 16 wins & 8 no...           NaN
# 10    Nominated for 2 Oscars. Another 9 wins & 18 no...           NaN
# 11    Won 3 Oscars. Another 235 wins & 326 nominations.   $50,628,650
# 12    Nominated for 6 Oscars. Another 23 wins & 141 ...   $18,329,466
# 13                                                  NaN           NaN
# 14                                                  NaN           NaN
# 15    Nominated for 1 Oscar. Another 28 wins & 43 no...           NaN
# 16                                                  NaN           NaN
# 17    Nominated for 1 Oscar. Another 1 win & 1 nomin...           NaN
# 18                                                  NaN           NaN
# 19       Nominated for 3 Oscars. Another 3 nominations.           NaN
# 20       Won 1 Oscar. Another 20 wins & 26 nominations.           NaN
# 21        Won 2 Oscars. Another 2 wins & 3 nominations.           NaN
# 22       Won 1 Oscar. Another 13 wins & 10 nominations.      $135,620
# 23    Nominated for 5 Oscars. Another 1 win & 3 nomi...           NaN
# 24    Nominated for 1 Oscar. Another 12 wins & 67 no...    $5,663,854
# 25                                                  NaN           NaN
# 26               Nominated for 1 Oscar. Another 3 wins.           NaN
# 27    Nominated for 2 Oscars. Another 3 wins & 30 no...   $53,574,088
# 28                                                  NaN           NaN
# 29    Nominated for 1 Oscar. Another 8 wins & 10 nom...           NaN
# ...                                                 ...           ...
# 4470                                                NaN           NaN
# 4471                                                NaN           NaN
# 4472                                                NaN           NaN
# 4473  Nominated for 2 Oscars. Another 1 win & 1 nomi...           NaN
# 4474  Nominated for 2 Oscars. Another 11 wins & 5 no...           NaN
# 4475  Nominated for 1 Oscar. Another 3 wins & 3 nomi...           NaN
# 4476  Nominated for 1 Oscar. Another 3 wins & 1 nomi...           NaN
# 4477  Nominated for 1 Oscar. Another 1 win & 3 nomin...           NaN
# 4478  Nominated for 3 Oscars. Another 3 wins & 7 nom...           NaN
# 4479                                                NaN           NaN
# 4480  Nominated for 1 Oscar. Another 2 wins & 1 nomi...           NaN
# 4481                                                NaN           NaN
# 4482  Nominated for 1 Oscar. Another 16 wins & 53 no...    $1,882,275
# 4483                                                NaN           NaN
# 4484                                                NaN           NaN
# 4485     Won 2 Oscars. Another 9 wins & 12 nominations.           NaN
# 4486  Nominated for 1 Oscar. Another 4 wins & 10 nom...           NaN
# 4487  Nominated for 2 Oscars. Another 6 wins & 14 no...           NaN
# 4488    Won 1 Oscar. Another 87 wins & 171 nominations.   $95,720,716
# 4489     Won 1 Oscar. Another 45 wins & 65 nominations.  $341,264,012
# 4490     Won 3 Oscars. Another 4 wins & 16 nominations.           NaN
# 4491  Nominated for 1 Oscar. Another 1 win & 6 nomin...           NaN
# 4492  Nominated for 1 Oscar. Another 1 win & 5 nomin...           NaN
# 4493  Nominated for 1 Oscar. Another 15 wins & 22 no...           NaN
# 4494                       Won 1 Oscar. Another 6 wins.           NaN
# 4495             Nominated for 1 Oscar. Another 2 wins.           NaN
# 4496                Won 1 Oscar. Another 5 nominations.           NaN
# 4497             Nominated for 1 Oscar. Another 3 wins.           NaN
# 4498  Nominated for 1 Oscar. Another 6 wins & 3 nomi...           NaN
# 4499                                                NaN           NaN
#
#                                 Country          DVD  \
# 0                                   NaN          NaN
# 1                 Austria, West Germany          NaN
# 2                             Australia    18-Sep-01
# 3                           USA, France    30-Jan-01
# 4                                   NaN          NaN
# 5                                   USA    16-Jan-01
# 6                                   USA    27-Aug-97
# 7                               USA, UK    03-Apr-01
# 8                                Russia    14-Jul-09
# 9                                   USA    06-Mar-01
# 10                                  USA    31-Mar-98
# 11                              USA, UK    04-Mar-14
# 12                      USA, UK, France    01-Mar-11
# 13                                  USA          NaN
# 14                                  NaN          NaN
# 15                                  USA    07-Oct-16
# 16                          New Zealand          NaN
# 17                                  USA    02-Jul-02
# 18                       Czechoslovakia          NaN
# 19                                  USA    23-Mar-99
# 20                                  USA    14-Jan-14
# 21                                  USA    20-May-03
# 22                              UK, USA    25-Aug-98
# 23                                  USA    25-Aug-98
# 24                                  USA    28-Mar-17
# 25                                  USA          NaN
# 26                          Netherlands          NaN
# 27                                  USA    08-Jan-08
# 28                                  USA          NaN
# 29                                  USA    08-Jan-02
# ...                                 ...          ...
# 4470                                USA  21 Oct 2003
# 4471                                USA          NaN
# 4472                                USA          NaN
# 4473                                USA  20 Jul 1994
# 4474                                USA  03 Nov 1998
# 4475                                USA  01 Jun 2004
# 4476                                USA  14 Feb 2006
# 4477                                USA  02 Dec 2003
# 4478                                 UK          NaN
# 4479                                USA          NaN
# 4480                                USA          NaN
# 4481                                USA          NaN
# 4482     Italy, France, UK, Switzerland  01 Mar 2016
# 4483                                USA          NaN
# 4484                                USA          NaN
# 4485                    France, Algeria  02 Jul 2002
# 4486  Czech Republic, Slovakia, Austria  08 Feb 2005
# 4487                                USA  06 Nov 2001
# 4488          USA, United Arab Emirates  19 Mar 2013
# 4489                                USA  07 Jun 2016
# 4490                        Greece, USA  03 Aug 2004
# 4491                        Netherlands  08 Jul 2003
# 4492                            UK, USA  16 Sep 2003
# 4493                                USA  28 Aug 2001
# 4494                                USA  03 Nov 2009
# 4495                             Canada          NaN
# 4496                            UK, USA  03 Oct 2000
# 4497                             France  20 Aug 2002
# 4498                             Sweden          NaN
# 4499                                NaN          NaN
#
#                                                Director             Error  \
# 0                                                   NaN  Movie not found!
# 1                                        Wolfgang Glück               NaN
# 2                                          Peter Faiman               NaN
# 3                                    Bertrand Tavernier               NaN
# 4                                                   NaN  Movie not found!
# 5                                        Norman Jewison          Face/Off
# 6                                         Blake Edwards               NaN
# 7                                            Kevin Lima               NaN
# 8                                      Nikita Mikhalkov               NaN
# 9                                          Sidney Lumet               NaN
# 10                                        Terry Gilliam               NaN
# 11                                        Steve McQueen               NaN
# 12                                          Danny Boyle               NaN
# 13                                        Jonathan Heap               NaN
# 14                                                  NaN  Movie not found!
# 15                                         Ava DuVernay               NaN
# 16                                                  NaN               NaN
# 17                                        Peter H. Hunt               NaN
# 18                                         Václav Krska               NaN
# 19                                     Steven Spielberg               NaN
# 20                                       Morgan Neville               NaN
# 21                                    Richard Fleischer               NaN
# 22                                      Stanley Kubrick               NaN
# 23                                          Peter Hyams               NaN
# 24                                           Mike Mills               NaN
# 25                                      Robert M. Leeds               NaN
# 26                                        Paul Driessen               NaN
# 27                                        James Mangold               NaN
# 28                                      Carson Davidson               NaN
# 29                                            Spike Lee               NaN
# ...                                                 ...               ...
# 4470                                    Sidney Lanfield               NaN
# 4471                                       David Butler               NaN
# 4472                                Alexander Grasshoff               NaN
# 4473                                      George Sidney               NaN
# 4474                                         Mel Brooks               NaN
# 4475                                       Geoff Murphy               NaN
# 4476                                          John Ford               NaN
# 4477                                     Barry Levinson               NaN
# 4478                               Richard Attenborough               NaN
# 4479                              Pamela Conn, Sue Marx               NaN
# 4480                                      Bill Plympton               NaN
# 4481                                        Thomas Mead               NaN
# 4482                                   Paolo Sorrentino               NaN
# 4483                                                NaN               NaN
# 4484                                   Albert S. Rogell               NaN
# 4485                                       Costa-Gavras               NaN
# 4486                                      Ondrej Trojan               NaN
# 4487                                        Woody Allen               NaN
# 4488                                    Kathryn Bigelow               NaN
# 4489  Byron Howard, Rich Moore, Jared Bush(co-director)               NaN
# 4490                                 Michael Cacoyannis               NaN
# 4491                                 Paula van der Oest               NaN
# 4492                                      Robert Altman               NaN
# 4493                                  Steven Soderbergh               NaN
# 4494                                       Ray McKinnon               NaN
# 4495                                     Chris Landreth               NaN
# 4496                                         George Pal               NaN
# 4497                                         René Clair               NaN
# 4498                                       Bo Widerberg               NaN
# 4499                                                NaN  Movie not found!
#
#                                                   Genre  \
# 0                                                   NaN
# 1                                                 Drama
# 2                             Action, Adventure, Comedy
# 3                                          Drama, Music
# 4                                                   NaN
# 5                                Crime, Drama, Thriller
# 6                                       Comedy, Romance
# 7                             Adventure, Comedy, Family
# 8                                Crime, Drama, Thriller
# 9                                                 Drama
# 10                            Mystery, Sci-Fi, Thriller
# 11                            Biography, Drama, History
# 12                                     Biography, Drama
# 13                                        Sci-Fi, Short
# 14                                                  NaN
# 15                             Documentary, Crime, News
# 16                                   Documentary, Short
# 17                      Drama, Family, History, Musical
# 18                                       Drama, History
# 19                                  Action, Comedy, War
# 20                        Documentary, Biography, Music
# 21            Adventure, Drama, Family, Fantasy, Sci-Fi
# 22                                    Adventure, Sci-Fi
# 23                 Adventure, Mystery, Sci-Fi, Thriller
# 24                                        Comedy, Drama
# 25                                       Short, History
# 26                             Animation, Short, Comedy
# 27                        Action, Crime, Drama, Western
# 28                                                Short
# 29                                 Documentary, History
# ...                                                 ...
# 4470                           Comedy, Musical, Romance
# 4471                                   Musical, Romance
# 4472                                 Documentary, Music
# 4473                          Biography, Drama, History
# 4474                                             Comedy
# 4475                                    Action, Western
# 4476                                   Biography, Drama
# 4477              Adventure, Fantasy, Mystery, Thriller
# 4478                              Biography, Drama, War
# 4479                        Documentary, Short, Romance
# 4480                    Animation, Short, Comedy, Music
# 4481                                              Short
# 4482                      Comedy, Drama, Music, Romance
# 4483                          Documentary, Drama, Short
# 4484                                      Comedy, Music
# 4485                    Crime, Drama, History, Thriller
# 4486                                Drama, Romance, War
# 4487                                             Comedy
# 4488                                    Drama, Thriller
# 4489  Animation, Adventure, Comedy, Crime, Family, M...
# 4490                                      Comedy, Drama
# 4491                           Comedy, Fantasy, Romance
# 4492                             Drama, Horror, Mystery
# 4493                                              Drama
# 4494                                      Comedy, Short
# 4495                                   Animation, Short
# 4496                           Family, Fantasy, Musical
# 4497                                    Comedy, Musical
# 4498                            Drama, History, Romance
# 4499                                                NaN
#
#                                 Language  ...  Runtime  \
# 0                                    NaN  ...      NaN
# 1                                 German  ...   97 min
# 2                                English  ...   97 min
# 3                        English, French  ...  133 min
# 4                                    NaN  ...      NaN
# 5                                English  ...  119 min
# 6                                English  ...  122 min
# 7                                English  ...  100 min
# 8                       Russian, Chechen  ...  159 min
# 9                                English  ...   96 min
# 10                       English, French  ...  129 min
# 11                               English  ...  134 min
# 12                      English, Italian  ...   94 min
# 13                               English  ...   25 min
# 14                                   NaN  ...      NaN
# 15                               English  ...  100 min
# 16                                   NaN  ...   33 min
# 17                               English  ...  141 min
# 18                                 Czech  ...  126 min
# 19    English, Japanese, German, Spanish  ...  118 min
# 20                      English, Spanish  ...   91 min
# 21                               English  ...  127 min
# 22                      English, Russian  ...  149 min
# 23                      English, Russian  ...  116 min
# 24                               English  ...  119 min
# 25                               English  ...   31 min
# 26                                  None  ...   11 min
# 27                      English, Chinese  ...  122 min
# 28                               English  ...   10 min
# 29                               English  ...  102 min
# ...                                  ...  ...      ...
# 4470                             English  ...   88 min
# 4471                             English  ...   96 min
# 4472                             English  ...  104 min
# 4473                             English  ...  112 min
# 4474                     English, German  ...  106 min
# 4475                             English  ...  104 min
# 4476                             English  ...  100 min
# 4477                             English  ...  109 min
# 4478                             English  ...  124 min
# 4479                             English  ...   29 min
# 4480                             English  ...    3 min
# 4481                             English  ...   10 min
# 4482      English, Spanish, Swiss German  ...  124 min
# 4483                             English  ...   19 min
# 4484                             English  ...   72 min
# 4485            French, Russian, English  ...  127 min
# 4486              Czech, Russian, German  ...  150 min
# 4487                     English, German  ...   79 min
# 4488                     English, Arabic  ...  157 min
# 4489                             English  ...  108 min
# 4490                      English, Greek  ...  142 min
# 4491  Dutch, English, French, Portuguese  ...  106 min
# 4492                     English, French  ...  104 min
# 4493                             English  ...  100 min
# 4494                             English  ...   35 min
# 4495                             English  ...    6 min
# 4496                             English  ...   98 min
# 4497                              French  ...   97 min
# 4498                             Swedish  ...  110 min
# 4499                                 NaN  ...      NaN
#
#                                Title   Type Website  \
# 0                                NaN    NaN     NaN
# 1       '38 - Vienna Before the Fall  movie     NaN
# 2                   Crocodile Dundee  movie     NaN
# 3                    'Round Midnight  movie     NaN
# 4                                NaN    NaN     NaN
# 5                And Justice for All  movie     NaN
# 6                                 10  movie     NaN
# 7                     102 Dalmatians  movie     NaN
# 8                                 12  movie     NaN
# 9                       12 Angry Men  movie     NaN
# 10                        12 Monkeys  movie     NaN
# 11                  12 Years a Slave  movie     NaN
# 12                         127 Hours  movie     NaN
# 13                          12:01 PM  movie     NaN
# 14                               NaN    NaN     NaN
# 15                              13th  movie     NaN
# 16          140 Days Under the World  movie     NaN
# 17                              1776  movie     NaN
# 18                Revolucni rok 1848  movie     NaN
# 19                              1941  movie     NaN
# 20              20 Feet from Stardom  movie     NaN
# 21      20,000 Leagues Under the Sea  movie     NaN
# 22             2001: A Space Odyssey  movie     NaN
# 23    2010: The Year We Make Contact  movie     NaN
# 24                20th Century Women  movie     NaN
# 25                     24 Hour Alert  movie     NaN
# 26                          3 Misses  movie     NaN
# 27                      3:10 to Yuma  movie     NaN
# 28                       3rd Ave. El  movie     NaN
# 29                    4 Little Girls  movie     NaN
# ...                              ...    ...     ...
# 4470           You'll Never Get Rich  movie     NaN
# 4471             You're a Sweetheart  movie     NaN
# 4472                 Young Americans  movie     NaN
# 4473                      Young Bess  movie     NaN
# 4474              Young Frankenstein  movie     NaN
# 4475                   Young Guns II  movie     NaN
# 4476               Young Mr. Lincoln  movie     NaN
# 4477           Young Sherlock Holmes  movie     NaN
# 4478                   Young Winston  movie     NaN
# 4479                  Young at Heart  movie     NaN
# 4480                       Your Face  movie     NaN
# 4481           Your National Gallery  movie     NaN
# 4482                           Youth  movie     NaN
# 4483                 Youth in Crisis  movie     NaN
# 4484                 Youth on Parade  movie     NaN
# 4485                               Z  movie     NaN
# 4486                          Zelary  movie     NaN
# 4487                           Zelig  movie     NaN
# 4488                Zero Dark Thirty  movie     NaN
# 4489                        Zootopia  movie     NaN
# 4490                 Zorba the Greek  movie     NaN
# 4491                        Zus & Zo  movie     NaN
# 4492                          Images  movie     NaN
# 4493        Sex, Lies, and Videotape  movie     NaN
# 4494                  The Accountant  movie     NaN
# 4495                         The End  movie     NaN
# 4496                       Tom Thumb  movie     NaN
# 4497               À Nous la Liberté  movie     NaN
# 4498                       Adalen 31  movie     NaN
# 4499                             NaN    NaN     NaN
#
#                                                  Writer  Year     imdbID  \
# 0                                                   NaN   NaN        NaN
# 1     Friedrich Torberg (novel), Wolfgang Glück, Lid...  1986  tt0090554
# 2     Ken Shadie (screenplay), John Cornell (screenp...  1986  tt0090555
# 3     David Rayfiel (screenplay), Bertrand Tavernier...  1986  tt0090557
# 4                                                   NaN   NaN        NaN
# 5                        Valerie Curtin, Barry Levinson  1979  tt0078718
# 6                                         Blake Edwards  1979  tt0078721
# 7     Dodie Smith (novel), Kristen Buckley (story), ...  2000  tt0211181
# 8     Nikita Mikhalkov, Aleksandr Novototskiy-Vlasov...  2007  tt0488478
# 9     Reginald Rose (story), Reginald Rose (screenplay)  1957  tt0050083
# 10    Chris Marker (film La Jetée), David Webb Peopl...  1995  tt0114746
# 11    John Ridley (screenplay by), Solomon Northup (...  2013  tt2024544
# 12    Danny Boyle (screenplay), Simon Beaufoy (scree...  2010  tt1542344
# 13    Stephen Tolkin, Jonathan Heap, Richard Lupoff ...  1990  tt0098962
# 14                                                  NaN   NaN        NaN
# 15                        Spencer Averick, Ava DuVernay  2016  tt5895028
# 16                                                  NaN  1964  tt0057806
# 17    Peter Stone (book), Sherman Edwards (based on ...  1972  tt0068156
# 18    K.J. Benes (screenplay), Milos Václav Kratochv...  1949  tt0152184
# 19    Robert Zemeckis (screenplay), Bob Gale (screen...  1979  tt0078723
# 20                                                  NaN  2013  tt2396566
# 21                             Earl Felton (screenplay)  1954  tt0046672
# 22    Stanley Kubrick (screenplay), Arthur C. Clarke...  1968  tt0062622
# 23    Arthur C. Clarke (novel), Peter Hyams (screenp...  1984  tt0086837
# 24                                           Mike Mills  2016  tt4385888
# 25    Beirne Lay Jr. (screenplay), Richard L. Breen ...  1955  tt0047791
# 26                               Paul Driessen (script)  1998  tt0239206
# 27    Halsted Welles (screenplay), Michael Brandt (s...  2007  tt0381849
# 28                                                  NaN  1955  tt0047792
# 29                                                  NaN  1997  tt0118540
# ...                                                 ...   ...        ...
# 4470  Michael Fessier (original screenplay), Ernest ...  1941  tt0034409
# 4471  Warren Wilson (story), Maxwell Shane (story), ...  1937  tt0029809
# 4472                                Alexander Grasshoff  1967  tt0062515
# 4473  Margaret Irwin (novel), Jan Lustig, Arthur Wim...  1953  tt0046564
# 4474  Gene Wilder (screen story and screenplay), Mel...  1974  tt0072431
# 4475                John Fusco (characters), John Fusco  1990  tt0100994
# 4476                 Lamar Trotti (original screenplay)  1939  tt0032155
# 4477  Arthur Conan Doyle (characters), Chris Columbu...  1985  tt0090357
# 4478  Winston Churchill (based upon "My Early Life: ...  1972  tt0069528
# 4479                                                NaN  1987  tt0094363
# 4480                   Maureen McElheron, Bill Plympton  1987  tt0094364
# 4481                                                NaN  1945  tt0038265
# 4482     Paolo Sorrentino, Virginia Jewiss (adaptation)  2015  tt3312830
# 4483                                                NaN  1943  tt0036555
# 4484  George Carleton Brown (original screenplay), F...  1942  tt0035587
# 4485  Vasilis Vasilikos (novel), Jorge Semprún (dial...  1969  tt0065234
# 4486            Kveta Legátová (novel), Petr Jarchovský  2003  tt0288330
# 4487                                        Woody Allen  1983  tt0086637
# 4488                                          Mark Boal  2012  tt1790885
# 4489  Byron Howard (story by), Rich Moore (story by)...  2016  tt2948356
# 4490  Nikos Kazantzakis (from the novel "The Life an...  1964  tt0057831
# 4491                                 Paula van der Oest  2001  tt0245157
# 4492               Robert Altman, Susannah York (novel)  1972  tt0068732
# 4493                                  Steven Soderbergh  1989  tt0098724
# 4494                                       Ray McKinnon  2001  tt0222675
# 4495                       Chris Landreth, Robin Bargar  1995  tt0112958
# 4496  Ladislas Fodor (screenplay), Jacob Grimm (base...  1958  tt0052427
# 4497                  René Clair (story and screenplay)  1931  tt0022599
# 4498                                       Bo Widerberg  1969  tt0065261
# 4499                                                NaN   NaN        NaN
#
#      imdbRating imdbVotes totalSeasons
# 0           NaN       NaN          NaN
# 1           6.8       101          NaN
# 2           6.6    86,770          NaN
# 3           7.4     4,337          NaN
# 4           NaN       NaN          NaN
# 5           7.4    28,179          NaN
# 6           6.1    14,213          NaN
# 7           4.9    32,501          NaN
# 8           7.7    13,327          NaN
# 9           8.9   615,624          NaN
# 10          8.0   546,302          NaN
# 11          8.1   590,624          NaN
# 12          7.6   329,847          NaN
# 13          7.6     1,143          NaN
# 14          NaN       NaN          NaN
# 15          8.2    20,569          NaN
# 16          6.5        11          NaN
# 17          7.6     7,249          NaN
# 18          6.5         6          NaN
# 19          5.8    29,638          NaN
# 20          7.4    11,491          NaN
# 21          7.2    26,637          NaN
# 22          8.3   556,266          NaN
# 23          6.8    47,405          NaN
# 24          7.3    33,802          NaN
# 25          6.1        48          NaN
# 26          6.5       185          NaN
# 27          7.7   273,888          NaN
# 28          7.1        50          NaN
# 29          7.8     2,530          NaN
# ...         ...       ...          ...
# 4470        6.8     1,909          NaN
# 4471        6.3        48          NaN
# 4472        6.9        36          NaN
# 4473        6.7     1,216          NaN
# 4474        8.0   135,440          NaN
# 4475        6.5    29,072          NaN
# 4476        7.6     6,791          NaN
# 4477        6.8    17,820          NaN
# 4478        6.7     1,935          NaN
# 4479        7.0        27          NaN
# 4480        7.0       951          NaN
# 4481        NaN       NaN          NaN
# 4482        7.3    66,215          NaN
# 4483        6.8        14          NaN
# 4484        5.6        23          NaN
# 4485        8.3    21,721          NaN
# 4486        7.7     3,155          NaN
# 4487        7.7    37,660          NaN
# 4488        7.4   255,941          NaN
# 4489        8.0   394,091          NaN
# 4490        7.7    19,035          NaN
# 4491        6.3     1,518          NaN
# 4492        7.2     4,442          NaN
# 4493        7.2    45,568          NaN
# 4494        7.7       850          NaN
# 4495        6.2       201          NaN
# 4496        6.5     2,114          NaN
# 4497        7.6     3,724          NaN
# 4498        7.5     1,109          NaN
# 4499        NaN       NaN          NaN
#
# [4500 rows x 28 columns]

# %% [markdown]
# ### Scrape script data

# %%
import csv
import os
import pandas as pd
import re
import requests
import string
import sys
from bs4 import BeautifulSoup
from time import sleep

oscar_data = pd.read_csv('oscar_data.csv')
filename   = 'movie_scripts.csv'

def write_script_data(movie_script_dict):
    if os.path.exists(filename):
        append_write = 'a' # append if already exists
    else:
        append_write = 'w' # make a new file if not
    with open(filename, append_write, newline='') as infile:
        writer = csv.writer(infile)
        for key in movie_script_dict:
            if movie_script_dict[key] != None:
                try:
                    print('Flushing to csv: {}'.format(key))
                    year,script = movie_script_dict[key]
                    writer.writerow([key, year, script])
                except TypeError as e:
                    print('Error, skipping writing this movie script...')
                    print(e)
                    print(key)
                    print(movie_script_dict[key])

def get_movie_script(movie_name, year):
    # Search to see if movie in Springfield database
    print('Searching db for: {}'.format(movie_name))
    movie_script_url = r'https://www.springfieldspringfield.co.uk/movie_scripts.php?search={}'.format(movie_name)
    data = requests.get(movie_script_url).text
    parser = BeautifulSoup(data, 'html.parser')
    tags = parser.find_all('a', {'class':"script-list-item"}) # Should find first search item
    if tags == None:
        return None
    script_url = None
    for movie_tag in tags:
        result_text = movie_tag.text
        match = re.search('(.+) \((\d\d\d\d)\)', movie_tag.text)
        if match == None:
            return None
        tag_title = match.group(1)
        tag_year = int(match.group(2))
        # Remove punctuation and lowercase
        exclude = set(string.punctuation)
        movie_name = ''.join(ch for ch in movie_name.lower() if ch not in exclude)
        tag_title  = ''.join(ch for ch in tag_title.lower() if ch not in exclude)
        # Only match if name is exact, and year within +-1
        if movie_name in tag_title and abs(year - tag_year) <= 1:
            script_url = 'https://www.springfieldspringfield.co.uk/{}'.format(movie_tag['href'])
            break
    if not script_url:
        return None

    # Get the script text from another url
    print(' Gathering script...')
    script_html = requests.get(script_url).text
    parser = BeautifulSoup(script_html, 'html.parser')
    script_container = parser.find('div', {'class':"scrolling-script-container"})
    script = script_container.text.strip()
    return script

movie_script_dict = {}
# Parse through previous csv - don't re scrape existing data
if os.path.exists(filename):
    prior_script_data = pd.read_csv(filename, header=None, encoding="ISO-8859-1")
    for movie_name in prior_script_data.iloc[:,0]:
        movie_script_dict[movie_name] = None
        
movie_set = set()
for index,row in oscar_data.iterrows():
    movie_set.add((row['entity'], row['year']))

flush_count = 0
for movie_name, year in movie_set:
    if movie_name in movie_script_dict:
        continue
    try:
        script = get_movie_script(movie_name, year)
    except Exception as e:
        print(' Error getting html data...')
        print(e)
        sleep(5)
        continue
    if script == None:
        continue
    movie_script_dict[movie_name] = (year,script)
    flush_count += 1
    
    # Flush to file when dict gets too large
    if flush_count >= 10:
        write_script_data(movie_script_dict)
        movie_script_dict = dict.fromkeys(movie_script_dict, None)
        flush_count = 0
